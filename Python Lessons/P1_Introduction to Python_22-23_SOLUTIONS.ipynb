# %% [markdown]
# # Introduction to Python: Part 1
#
# Welcome to the Beginner Python crash course! In the AI & Machine Learning club, we will be using Python to code our projects!
#
# In this series of lessons, we will walk you through fundamental Python knowledge that will assist you with your projects. Keep in mind that this is a very condensed course, so it would be very important for you to practice and review this on your own as well. If you have any questions, try figuring it out on your own at first! Some great resources are StackOverflow, MDM, YouTube, and W3Schools. If the answer isn't online, ask a peer! Then, feel free to ask a leader or a teacher as a last resort.
#
# Note: This tutorial is for beginners or people who need a recap of Python. If you already have a sizeable knowledge of Python including syntax, loops, arrays, etc, feel free to skip these and move to projects.

# %% [markdown]
# ## First off, what is Python?
#
# The big and complicated definition is: **a high-level, intepreted, and general purpose programming language.** Let's dissect it.
#
# 1) **High-level** means that Python is easy to learn. Python doesn't require a complex understanding of computers to use it. A low-level language is more "machine friendly" rather than "people friendly." An example of this is the C programming language.
#
# 2) **Interpreted** means that to develop a Python program, you write the code in a file known as source code. To execute/run this code, it needs to be converted into machine language that the computer understands. When a Python file is executed, the Python interpreter turns the source code into machine code, line by line. The opposite of this is a compiled language, like Java. This means they use a compiler that compiles the source code *before* the program is executed.
#
# 3) **General-purpose** means that Python can be used in a variety of domains, such as websites, apps, data science, software, and machine learning.

# %% [markdown]
# ## A Note on Syntax Before We Get Started
#
# Python uses whitespace as a way to seperate code. If you've seen or used other languages like Java or JavaScript, you'll know that they seperate statements via semicolons (;).
#
# Making sure your Python code has consistent and has even spacing, or you'll run into some errors. The program below has some whitespace errors. Try fixing the whitespace until it prints out 33.

# %%
   a    = 10;
b                      = 11
 c = 12
   print(a + b + c)
# Out:
#   File "<ipython-input-3-3996fee2bd53>", line 3
#     c = 12
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## Your First Line of Python
#
# Okay, let's get started with some coding!
#
# If you're in GitHub right now, you will need to type the line of code below into Replit in order to run it.

# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Your First Variable
#
# In programming, we use something called a **variable**. It's similar to what you have learned in math.

# %%
x = 10

# %% [markdown]
# When you run the cell above, you create a variable named `x` assigned with the value of 10.
#
# The next time you refer to `x` in your code, it will remember that it has been assigned 10. Think of variables as labels that have a value assigned to it.

# %% [markdown]
# ## Printing
#
# When we run a Python program, we will only receive what we set to print to the screen. Run the code below to see how it works:

# %%
# Note that running this line of code yields no result
x = 20

# %%
# However, running this gives you a result
y = 25
print(y)
# Out:
# 25

# %% [markdown]
# Note that `print` cannot have a capital P.

# %% [markdown]
# Time to practice! Add a line to the code block below to print the value of `z`.

# %%
z = 35
### YOUR CODE HERE ### 

# By the way, when you add a hashtag to the front of a line of code, this tells the program to treat that line as a comment
# Programmers leave comments on their code to leave helpful notes for themselves and communicate information to other programmers!

# %% [markdown]
# What happens if we use multiple print commands? They will automatically print on separate lines:

# %%
print("Hello!")
print("How are you feeling today?")
# Out:
# Hello!
# How are you feeling today?

# %% [markdown]
# An useful way to use variables is to print out messages that have the value of the variable in the message:

# %%
num_pencils = 5
print("I have", num_pencils, "pencils.")
# Out:
# I have 5 pencils.

# %% [markdown]
# Notice that variables don't have to just be single lettered, such as `x`, `y`, and `z`. They can also be composed of letters, such as the `num_pencils` you saw above.

# %% [markdown]
# ## Coding Challenge #1
# Look in the cell below for instructions:

# %%
num_books = 100
# Using the variable num_books, Write a print statement below to say "I own 100 books."

### YOUR CODE HERE ### 
print("I own 100 books.")

# %% [markdown]
# ## Rules on Naming Variables
#
# Like many other things, there are rules that you must follow when naming variables.

# %% [markdown]
# For example, variables require the correct input of lowercase and uppercase letters. This means a variable named `something` and one named `Something` are different! See what happes when we run code with this mistake:

# %%
thing = 1
print(Thing)

# %% [markdown]
# This is because we created a variable named `thing` but not one named `Thing`.
#
# As you have seen in earlier examples, variables can have letters, numbers, and underscores in them. However, there are restrictions.
#
# Run the following code blocks to see which ones raise errors:

# %%
thing_2 = 5

# %%
thing-2 = 5
# Out:
#   File "<ipython-input-2-cfe80068f3a2>", line 1
#     thing-2 = 5
#                ^
# SyntaxError: can't assign to operator

# %%
2_thing = 5
# Out:
#   File "<ipython-input-18-5c288ad0de83>", line 1
#     2_thing = 5
#      ^
# SyntaxError: invalid token

# %%
random_variable = 5

# %%
random variable = 5
# Out:
#   File "<ipython-input-21-bc7ae6e8509a>", line 1
#     random variable = 5
#                   ^
# SyntaxError: invalid syntax

# %% [markdown]
# From the above examples, you should notice:
#
# *   You cannot use any special characters (such as`-` or `+`) or punctuation (such as `.` or `,`). That's why `thing-2 = 5` doesn't work.
# *   You can only start a variable name with a letter or underscore (no numbers), so you cannot use `2_thing = 5`.
# *   You cannot put a space in a variable name, so you cannot write `random variable = 5`.

# %% [markdown]
# As a final note, as shown below, you also can't use "reserved keywords" as variable names. "Reserved keywords" are special words in Python that have specific jobs and do specific things in your code. For example, one reserved keyword is `for`. (You will learn what `for`does later on.) It brings a syntax error in your code:

# %%
for = 10
# Out:
#   File "<ipython-input-24-597287a2d762>", line 1
#     for = 10
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Data Types
#
# As a review, what we **name** our variable is what goes in front of the equal sign and what we **assign** to are variables are what goes right after the equal sign.
#
# So far, we have found out that we can use letters, words, and numbers in **naming** our variables. However, we can actually also **assign** different types of data to our variables!

# %% [markdown]
# We can assign text to variables by using quotations or apostrophes. These data types are known as Strings, which is a series of characters. Think of it as words or sentences.

# %%
some_string = "Apples"
some_string_2 = 'Oranges'
print(some_string)
print(some_string_2)
# Out:
# Apples
# Oranges

# %% [markdown]
# Numbers across Python are put into 2 categories: Integers and Floats. If your number is a whole number, it is classified as an integer. Numbers with decimal values are classified as floats.

# %%
# We can also assign numbers with decimal points to our variables
some_number = 13.45 #This is a float
amazing_num = 938274298 # This is an integer

# %% [markdown]
# ## Coding Challenge #2

# %%
# Initialize your own variable below (title it "name") and assign it to a string with a your name. Make another variable (title it 'age") with your age. 
#Then, print everything in this format: "'name' is age 'years' old" 
#If my name was Bob and I was 2 years old, it should print "Bob is 2 years old."

### YOUR CODE HERE ### 

name = "Yeee"
age = 1
print(name, "is", age, "years old")
# Out:
# Yeee is 1 years old

# %% [markdown]
# ## Math in Python
#
# Python can also be used as a math calculator. In machine learning, we will often deal with complex numbers and equations, so this is when a calculator comes handy!
#
# For example, if we were asked to multiply 23 and 45, we could type it right into Python:

# %%
print(23*45)
# Out:
# 1035

# %% [markdown]
# But what if we need to use this answer for future calculations? We can save it as a variable and use it later!

# %%
a = 23 * 45
b = 4
c = a * b
print(c)
# Out:
# 4140

# %% [markdown]
# ### Math Operators
#
# See how we do mathematical operations in Python below:

# %%
addition = 7 + 3
subtraction = 18 - 7

multiplication = 12 * 3
division = 36 / 6

exponents = 3 ** 2

add_sum = addition + subtraction


# Notice that if we run this cell block, there is no output (so we can't check our results)
# Add a print statements so you can check if the calculations come out as expected!

### YOUR CODE HERE ### 
print(addition)
print(subtraction)
print(multiplication)
print(division)
print(add_sum)
# Out:
# 10
# 11
# 36
# 6.0
# 21

# %% [markdown]
# Additionally, one math operation you may have not have seen before is called **modulo**. It can sometimes be useful because it returns the remainder after you divide.
#
# For example:

# %%
modulo = 33 % 10
print(modulo)

# When you divide 33 by 10, you get 3 with a remainder of 3
# The modulo (%) operator returns that 3
# Out:
# 3

# %% [markdown]
# ### Order of Operations and Parentheses
#
# Order of operations and parentheses work the same way in Python as you would expect in math.

# %%
some_number = (47 + 3) * 2 / 10
print(some_number)
# Out:
# 10.0

# %% [markdown]
# However, an exception is that you cannot do multiplication by just having parentheses:

# %%
some_number_2 = 2 (5 + 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-fcd17ba6befa> in <module>()
# ----> 1 some_number_2 = 2 (5 + 5)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### A Little More Math in Python
#
# So far, we've only been creating new variables. However, variables in Python can be updated to hold new values. For example:

# %%
a = 10
print(a)
a = 20
print(a)
# Out:
# 10
# 20

# %% [markdown]
# What if we wanted to add 5 to the value of `a`?

# %%
a = 20
a += 5
print(a)
# Out:
# 25

# %% [markdown]
# The `+=` tells the computer to add 5 to the original value of `a`, and then update `a` to equal this new number. It's the same thing as `a = a + 5` but way shorter and easier to write!

# %% [markdown]
# Below is a longer example with other operations. What do you think will be printed out? Try calculating this yourself (without technology), and then add a print statement to verify the accuracy of your answer:

# %%
unknown = 5
unknown += 5
unknown -= 2
unknown *= 8
unknown /= 4
unknown %= 3

##ADD a print statement here
print(unknown)
# Out:
# 1.0

# %% [markdown]
# ## The input statement
#
# If you set a variable to an input statement, the program will ask for it. The syntax for an input statement is just input("A string here"). This string will be displayed as a prompt. Input statements return a string.
#
# To return an integer, you need to put the input statement inside of an int() statement. Here's what it looks like

# %%
x = int(input("Enter a value for x: "))
print(x)

# %% [markdown]
# ## Coding Challenge 3

# %%
#Write a program that finds the area of a triangle. Make 2 variables: base and height. Make it so that these variables ask for an input (which should be a number). 
#Then, create another variable called area. This variable will be a math calculation that finds the area of the triangle, and print it.
#Let's also develop some developer skills! Add some comments to each line of code so we can understand it better. You don't need to put comments on everything, but lets do so for this exercise.



## YOUR CODE HERE ##
base = int(input("Enter the base: ")) #Ask for the base
height = int(input("Enter the height: ")) #Ask for the height
area = (base * height) / 2 #Find the total area and put that number into a variable
print(area) #Print the area of the triangle
# Out:
# Enter the base: 112
# Enter the height: 1221
# 68376.0
